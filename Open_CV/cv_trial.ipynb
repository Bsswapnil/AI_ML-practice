# %%
import cv2

print("OpenCV version:", cv2.__version__)
# Out:
# OpenCV version: 4.10.0

# %%
from PIL import Image

import matplotlib.pyplot as plt
import numpy as np

# %%
# img_chess_path = os.path.join(os.path.dirname(__file__), 'images', 'chess.png')
img_chess_path = "/home/swapnil/ACL/OpenCV/OpenCV-Python-Tutorials-and-Projects/Resources/chess.jpg"
img_chess = cv2.imread(img_chess_path)
plt.imshow(img_chess)

# %%
image_chess_rgb = cv2.cvtColor(img_chess, cv2.COLOR_BGR2RGB)

# Display the image using Matplotlib
plt.imshow(image_chess_rgb)
# plt.axis('off')  # Optional: Turn off axis
plt.show()
